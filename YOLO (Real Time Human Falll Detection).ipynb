# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %cd yolov5
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16000, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 16000 (delta 20), reused 20 (delta 12), pack-reused 15967
# Receiving objects: 100% (16000/16000), 14.59 MiB | 14.13 MiB/s, done.
# Resolving deltas: 100% (10986/10986), done.
# /content/yolov5
# Mounted at /content/drive

# %%
pip install -U -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 107.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 88.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 73.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 45.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.6/615.6 kB 50.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 117.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 37.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 55.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 37.4 MB/s eta 0:00:00
# ...

# %%
custom_yaml = """
train: /content/drive/MyDrive/Fall Detection/train
val: /content/drive/MyDrive/Fall Detection/valid
nc: 2
names: ['fall', 'not-fallen']
"""

with open('/content/custom.yaml', 'w') as yaml_file:
    yaml_file.write(custom_yaml)

import os
if os.path.exists('/content/custom.yaml'):
    print("Custom YAML configuration file created successfully.")
else:
    print("Failed to create the custom YAML configuration file.")
# Out:
# Custom YAML configuration file created successfully.

# %%
# %cd /content/yolov5

# !python train.py --img-size 640 --batch-size 16 --epochs 15 --data /content/custom.yaml
# Out:
# /content/yolov5
# train: weights=yolov5s.pt, cfg=, data=/content/custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=15, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-225-gbb9706e Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# Out:
# Mounted at /content/drive

# %%
import os

file_path = '/content/drive/.shortcut-targets-by-id/1DH2EQ4RUuHTC5RnFFvB83kSXImySRnQX/Fall Detection/train/images/rgb_0963_png.rf.0aa049b6c46dc16ded3aabb6c71fac3a.jpg'

if os.path.exists(file_path):
    print("The file exists.")
else:
    print("The file does not exist.")
# Out:
# The file does not exist.

# %%
custom_yaml = """
train: /content/drive/MyDrive/Fall Detection/train
val: /content/drive/MyDrive/Fall Detection/valid
test: /content/drive/MyDrive/Fall Detection/test
nc: 2
names: ['fall', 'not-fallen']
"""

with open('/content/custom.yaml', 'w') as yaml_file:
    yaml_file.write(custom_yaml)

# %%
# !python val.py --data /content/custom.yaml --weights /content/yolov5/runs/train/exp/weights/best.pt --img-size 640 --conf-thres 0.001 --iou-thres 0.6 --task test --project /content/drive/MyDrive/Fall\ Detection/test_results
# Out:
# val: data=/content/custom.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=/content/drive/MyDrive/Fall Detection/test_results, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-225-gbb9706e Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/drive/MyDrive/Fall Detection/test/labels... 51 images, 0 backgrounds, 0 corrupt: 100% 51/51 [00:43<00:00,  1.16it/s]
# test: New cache created: /content/drive/MyDrive/Fall Detection/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.01s/it]
# ...

# %%
results_dir = '/content/drive/MyDrive/Fall Detection/test_results/exp'
files = os.listdir(results_dir)
print(files)
# Out:
# ['val_batch0_pred.jpg', 'val_batch0_labels.jpg', 'val_batch1_pred.jpg', 'val_batch1_labels.jpg', 'PR_curve.png', 'P_curve.png', 'F1_curve.png', 'R_curve.png', 'confusion_matrix.png']

# %%
results_dir = '/content/drive/MyDrive/Fall Detection/test_results/exp'
files = os.listdir(results_dir)

for file in files:
    print(file)
# Out:
# val_batch0_pred.jpg
# val_batch0_labels.jpg
# val_batch1_pred.jpg
# val_batch1_labels.jpg
# PR_curve.png
# P_curve.png
# F1_curve.png
# R_curve.png
# confusion_matrix.png

# %%
from IPython.display import Image, display

results_dir = '/content/drive/MyDrive/Fall Detection/test_results/exp'
files = os.listdir(results_dir)

for file in files:
    if file.endswith('.jpg') or file.endswith('.png'):
        file_path = os.path.join(results_dir, file)
        display(Image(filename=file_path))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
results_dir = '/content/drive/MyDrive/Fall Detection/test_results/exp'
files = os.listdir(results_dir)

for file in files:
    if file.endswith('.jpg'):
        image_path = os.path.join(results_dir, file)
        display(Image(filename=image_path))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
results_dir = '/content/drive/MyDrive/Fall Detection/test_results/exp'
files = os.listdir(results_dir)

for file in files:
    if file.endswith('.png'):
        image_path = os.path.join(results_dir, file)
        display(Image(filename=image_path))

# %%
# !python detect.py --source /content/drive/MyDrive/humanFall.mp4 --weights /content/yolov5/runs/train/exp/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/humanFall.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-225-gbb9706e Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/1151) /content/drive/MyDrive/humanFall.mp4: 384x640 1 not-fallen, 82.0ms
# video 1/1 (2/1151) /content/drive/MyDrive/humanFall.mp4: 384x640 1 not-fallen, 11.7ms
# video 1/1 (3/1151) /content/drive/MyDrive/humanFall.mp4: 384x640 1 not-fallen, 11.0ms
# ...

# %%
results_dir = '/content/yolov5/runs/train/exp'
files = os.listdir(results_dir)

for file in files:
    if file.endswith('.png'):
        image_path = os.path.join(results_dir, file)
        display(Image(filename=image_path))

# %%
from google.colab import drive
drive.mount('/content/drive')
